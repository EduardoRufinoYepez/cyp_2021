# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoRufinoYepez/cyp_2021/blob/main/8_dic_2020_CyP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
suma_gas = 0
gasto = float(input("dame el gasto:"))
while( gasto != -1 ) :
  suma_gas = suma_gas + gasto #suma_gas += 1
  gasto= float(input("introduce un gasto:"))
print(f"la suma total es{ suma_gas } pesos")

# %%
cubo=0
num=float(input("Introduce un numero:"))
while (num !=-1):
  cubo=num**3
  print(f"El cubo del numero es {cubo}")
  num=float(input("Introduce un numero:"))

# %%
# Problema 3.1

sumpar = 0
sumimp = 0
cuepar = 0
I = 1
while I <= 5:
  num = int(input(" Introduce un numero entero: "))
  if num != 0:
    if ((-1) ** num) > 0: # num % 2
      sumpar = sumpar + num
      cuepar = cuepar + 1
    else:
       sumimp = sumimp + num 
  I = I + 1
propar= sumpar / cuepar
print(f" El promedio de los pares es: {propar} ") 
print(f" La suma de los impares es: {sumimp}")
# Out:
#  Introduce un numero entero: 1
#  Introduce un numero entero: 2
#  Introduce un numero entero: 3
#  Introduce un numero entero: 4
#  Introduce un numero entero: 5
#  El promedio de los pares es: 3.0
#  La suma de los impares es: 9

# %%
band = True
sumser = 0
I = 0
while I <= 1800:
  sumser = sumser + I
  print(f"{ I },", end= "")
  if band == True:
    band = False
    I = I + 3
  else:
    band = True
    I = I + 2
print("\nLa suma de la serie es:", sumser)
720
# Out:
# 0,3,5,8,10,13,15,18,20,23,25,28,30,33,35,38,40,43,45,48,50,53,55,58,60,63,65,68,70,73,75,78,80,83,85,88,90,93,95,98,100,103,105,108,110,113,115,118,120,123,125,128,130,133,135,138,140,143,145,148,150,153,155,158,160,163,165,168,170,173,175,178,180,183,185,188,190,193,195,198,200,203,205,208,210,213,215,218,220,223,225,228,230,233,235,238,240,243,245,248,250,253,255,258,260,263,265,268,270,273,275,278,280,283,285,288,290,293,295,298,300,303,305,308,310,313,315,318,320,323,325,328,330,333,335,338,340,343,345,348,350,353,355,358,360,363,365,368,370,373,375,378,380,383,385,388,390,393,395,398,400,403,405,408,410,413,415,418,420,423,425,428,430,433,435,438,440,443,445,448,450,453,455,458,460,463,465,468,470,473,475,478,480,483,485,488,490,493,495,498,500,503,505,508,510,513,515,518,520,523,525,528,530,533,535,538,540,543,545,548,550,553,555,558,560,563,565,568,570,573,575,578,580,583,585,588,590,593,595,598,600,603,605,608,610,613,615,618,620,623,625,628,630,633,635,638,640,643,645,648,65
# ...
